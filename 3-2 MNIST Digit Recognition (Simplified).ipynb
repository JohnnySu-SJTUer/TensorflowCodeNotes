# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

# %%
#load dataset
mnist = input_data.read_data_sets("MNIST_data",one_hot=True)
#define batch size
batch_size = 50
#calculate number of batches
n_batch = mnist.train.num_examples // batch_size

#define to placeholder
x = tf.placeholder(tf.float32, [None,784])
y = tf.placeholder(tf.float32, [None,10])

#create simple neural network
W = tf.Variable(tf.zeros([784,10]))
b = tf.Variable(tf.zeros([10]))
prediction = tf.nn.softmax(tf.matmul(x,W)+b)

#quadratic cost function
loss = tf.reduce_mean(tf.square(y-prediction))
#train with gradient descent
train_step = tf.train.GradientDescentOptimizer(0.3).minimize(loss)

#initialize variables
init = tf.global_variables_initializer()

#find accuracy of trained model
correct_prediction = tf.equal(tf.argmax(y,1),tf.argmax(prediction,1))

#convert a list of booleans into a single boolean of accuracy
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

with tf.Session() as sess:
    sess.run(init)
    for epoch in range(101):
        for batch in range(n_batch):
            batch_xs,batch_ys = mnist.train.next_batch(batch_size)
            sess.run(train_step, feed_dict={x:batch_xs,y:batch_ys})
        acc = sess.run(accuracy,feed_dict={x:mnist.test.images,y:mnist.test.labels})
        print("Iter "+str(epoch) + ",Testing Accuracy "+str(acc))
# Out:
# Extracting MNIST_data\train-images-idx3-ubyte.gz
# Extracting MNIST_data\train-labels-idx1-ubyte.gz
# Extracting MNIST_data\t10k-images-idx3-ubyte.gz
# Extracting MNIST_data\t10k-labels-idx1-ubyte.gz
# Iter 0,Testing Accuracy 0.8812
# Iter 1,Testing Accuracy 0.8968
# Iter 2,Testing Accuracy 0.9035
# Iter 3,Testing Accuracy 0.9071
# Iter 4,Testing Accuracy 0.9103
# Iter 5,Testing Accuracy 0.913
# Iter 6,Testing Accuracy 0.9142
# Iter 7,Testing Accuracy 0.916
# Iter 8,Testing Accuracy 0.9168
# Iter 9,Testing Accuracy 0.9175
# Iter 10,Testing Accuracy 0.9183
# Iter 11,Testing Accuracy 0.9186
# Iter 12,Testing Accuracy 0.9197
# Iter 13,Testing Accuracy 0.92
# Iter 14,Testing Accuracy 0.9212
# Iter 15,Testing Accuracy 0.9221
# Iter 16,Testing Accuracy 0.9215
# Iter 17,Testing Accuracy 0.9218
# Iter 18,Testing Accuracy 0.9223
# Iter 19,Testing Accuracy 0.9221
# Iter 20,Testing Accuracy 0.9226
# Iter 21,Testing Accuracy 0.923
# Iter 22,Testing Accuracy 0.9242
# Iter 23,Testing Accuracy 0.9242
# Iter 24,Testing Accuracy 0.9243
# Iter 25,Testing Accuracy 0.9248
# Iter 26,Testing Accuracy 0.9246
# Iter 27,Testing Accuracy 0.9248
# Iter 28,Testing Accuracy 0.9245
# Iter 29,Testing Accuracy 0.9254
# Iter 30,Testing Accuracy 0.9265
# Iter 31,Testing Accuracy 0.9261
# Iter 32,Testing Accuracy 0.9265
# Iter 33,Testing Accuracy 0.9251
# Iter 34,Testing Accuracy 0.9267
# Iter 35,Testing Accuracy 0.9261
# Iter 36,Testing Accuracy 0.927
# Iter 37,Testing Accuracy 0.9269
# Iter 38,Testing Accuracy 0.927
# Iter 39,Testing Accuracy 0.928
# Iter 40,Testing Accuracy 0.9274
# Iter 41,Testing Accuracy 0.928
# Iter 42,Testing Accuracy 0.9281
# Iter 43,Testing Accuracy 0.9267
# Iter 44,Testing Accuracy 0.9285
# Iter 45,Testing Accuracy 0.9287
# Iter 46,Testing Accuracy 0.9275
# Iter 47,Testing Accuracy 0.9284
# Iter 48,Testing Accuracy 0.9287
# Iter 49,Testing Accuracy 0.9288
# Iter 50,Testing Accuracy 0.9285
# Iter 51,Testing Accuracy 0.9291
# Iter 52,Testing Accuracy 0.9285
# Iter 53,Testing Accuracy 0.9288
# Iter 54,Testing Accuracy 0.9284
# Iter 55,Testing Accuracy 0.9286
# Iter 56,Testing Accuracy 0.9288
# Iter 57,Testing Accuracy 0.9284
# Iter 58,Testing Accuracy 0.9286
# Iter 59,Testing Accuracy 0.9293
# Iter 60,Testing Accuracy 0.9287
# Iter 61,Testing Accuracy 0.9295
# Iter 62,Testing Accuracy 0.9292
# Iter 63,Testing Accuracy 0.9284
# Iter 64,Testing Accuracy 0.9297
# Iter 65,Testing Accuracy 0.9286
# Iter 66,Testing Accuracy 0.9293
# Iter 67,Testing Accuracy 0.9291
# Iter 68,Testing Accuracy 0.9294
# Iter 69,Testing Accuracy 0.9293
# Iter 70,Testing Accuracy 0.9283
# Iter 71,Testing Accuracy 0.9296
# Iter 72,Testing Accuracy 0.9292
# Iter 73,Testing Accuracy 0.9295
# Iter 74,Testing Accuracy 0.9296
# Iter 75,Testing Accuracy 0.9287
# Iter 76,Testing Accuracy 0.9292
# Iter 77,Testing Accuracy 0.9296
# Iter 78,Testing Accuracy 0.9293
# Iter 79,Testing Accuracy 0.9302
# Iter 80,Testing Accuracy 0.9303
# Iter 81,Testing Accuracy 0.9302
# Iter 82,Testing Accuracy 0.9291
# Iter 83,Testing Accuracy 0.9295
# Iter 84,Testing Accuracy 0.9304
# Iter 85,Testing Accuracy 0.9305
# Iter 86,Testing Accuracy 0.9295
# Iter 87,Testing Accuracy 0.9296
# Iter 88,Testing Accuracy 0.93
# Iter 89,Testing Accuracy 0.9296
# Iter 90,Testing Accuracy 0.9296
# Iter 91,Testing Accuracy 0.9296
# Iter 92,Testing Accuracy 0.9306
# Iter 93,Testing Accuracy 0.9295
# Iter 94,Testing Accuracy 0.9303
# Iter 95,Testing Accuracy 0.9301
# Iter 96,Testing Accuracy 0.9298
# Iter 97,Testing Accuracy 0.9301
# Iter 98,Testing Accuracy 0.9296
# Iter 99,Testing Accuracy 0.9307
# Iter 100,Testing Accuracy 0.9304

# %%
'''
change parameters:

batch_size
initializer of W,b
learnint rate
optimizer
epoch

'''
